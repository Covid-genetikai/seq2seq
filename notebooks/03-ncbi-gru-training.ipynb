# %% [markdown]
# ## Character-level recurrent sequence-to-sequence model

# %% [markdown]
# Example from https://keras.io/examples/nlp/lstm_seq2seq/
# Older post https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %%
import numpy as np
import pandas as pd
from itertools import chain
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 8)

# %%
with np.load('data/ncbi_02/dataset.npz', allow_pickle = True) as data:
    encoder_input_data = data['encoder_input_data']
    decoder_input_data = data['decoder_input_data']
    decoder_target_data = data['decoder_target_data']
    token_index = data['token_index'].tolist()

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)
print(token_index)
# Out:
# (4368, 3822, 4)
# (4368, 3822, 4)
# (4368, 3822, 4)
# {'A': 0, 'C': 1, 'G': 2, 'T': 3}

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15561808070687915446
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7224164352
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 15582289229395797785
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 7741702144
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4914857555396846198
# physical_device_desc: "device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]
# 2021-11-12 14:40:40.486102: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-12 14:40:40.646710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:40.648040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:40.652110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:40.652443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:40.652747: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:40.653042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.221011: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.221384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.221694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.221995: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.222342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.222630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 6889 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2021-11-12 14:40:41.222931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 14:40:41.223225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:1 with 7383 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# ## Construct model

# %%
latent_dim = 256     # Latent dimensionality of the encoding space.
batch_size = 32      # Batch size for training.
patience = 10        # Patience for EarlyStop
epochs = 1000        # Number of epochs to train for.

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape = (None, encoder_input_data.shape[2]))
encoder = keras.layers.GRU(latent_dim, return_state = True)
encoder_outputs, state_h = encoder(encoder_inputs)

state_h = keras.layers.GaussianNoise(1.0)(state_h, training = True)
state_h = keras.layers.BatchNormalization(momentum = 0.6)(state_h)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape = (None, decoder_input_data.shape[2]))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder = keras.layers.GRU(latent_dim, return_sequences = True, return_state = True)
decoder_outputs, _ = decoder(decoder_inputs, initial_state = state_h)
decoder_dense = keras.layers.Dense(decoder_target_data.shape[2], activation = "softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file = 'model.png')

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# gru_2 (GRU)                     [(None, 256), (None, 201216      input_3[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 256)          0           gru_2[0][1]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256)          1024        gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     [(None, None, 256),  201216      input_4[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 4)      1028        gru_3[0][0]
# ==================================================================================================
# Total params: 404,484
# Trainable params: 403,972
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.compile(
    optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"]
)

es = EarlyStopping(monitor='val_loss', min_delta = 0, patience = patience, 
                   verbose = 1, restore_best_weights = True)

log = model.fit(
    [ encoder_input_data, decoder_input_data ],
    decoder_target_data,
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [ es ],
    validation_split = 0.2,
)
# Out:
# 2021-11-12 14:40:57.572542: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 2021-11-12 14:40:59.705712: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8300
# 110/110 [==============================] - 38s 324ms/step - loss: 1.3098 - accuracy: 0.3654 - val_loss: 1.2769 - val_accuracy: 0.3906
# Epoch 2/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 1.2329 - accuracy: 0.4303 - val_loss: 1.1769 - val_accuracy: 0.4770
# Epoch 3/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 1.1189 - accuracy: 0.5076 - val_loss: 1.0383 - val_accuracy: 0.5513
# Epoch 4/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.9657 - accuracy: 0.5956 - val_loss: 0.8711 - val_accuracy: 0.6466
# Epoch 5/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 0.7719 - accuracy: 0.6942 - val_loss: 0.6664 - val_accuracy: 0.7386
# Epoch 6/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.5692 - accuracy: 0.7916 - val_loss: 0.4662 - val_accuracy: 0.8336
# Epoch 7/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.3876 - accuracy: 0.8789 - val_loss: 0.2618 - val_accuracy: 0.9425
# Epoch 8/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.2578 - accuracy: 0.9353 - val_loss: 0.1391 - val_accuracy: 0.9866
# Epoch 9/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.1674 - accuracy: 0.9633 - val_loss: 0.0821 - val_accuracy: 0.9932
# Epoch 10/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.1148 - accuracy: 0.9753 - val_loss: 0.0588 - val_accuracy: 0.9944
# Epoch 11/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 0.0837 - accuracy: 0.9826 - val_loss: 0.0389 - val_accuracy: 0.9958
# Epoch 12/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 0.0606 - accuracy: 0.9868 - val_loss: 0.0288 - val_accuracy: 0.9963
# Epoch 13/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 0.0417 - accuracy: 0.9911 - val_loss: 0.0222 - val_accuracy: 0.9965
# Epoch 14/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0380 - accuracy: 0.9916 - val_loss: 0.0318 - val_accuracy: 0.9940
# Epoch 15/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.0327 - accuracy: 0.9924 - val_loss: 0.0165 - val_accuracy: 0.9974
# Epoch 16/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0283 - accuracy: 0.9936 - val_loss: 0.0144 - val_accuracy: 0.9979
# Epoch 17/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.0245 - accuracy: 0.9943 - val_loss: 0.0129 - val_accuracy: 0.9979
# Epoch 18/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 0.0187 - accuracy: 0.9958 - val_loss: 0.0167 - val_accuracy: 0.9976
# Epoch 19/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0210 - accuracy: 0.9954 - val_loss: 0.0110 - val_accuracy: 0.9982
# Epoch 20/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0214 - accuracy: 0.9953 - val_loss: 0.0124 - val_accuracy: 0.9980
# Epoch 21/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0124 - accuracy: 0.9973 - val_loss: 0.0115 - val_accuracy: 0.9976
# Epoch 22/1000
# 110/110 [==============================] - 34s 311ms/step - loss: 0.0398 - accuracy: 0.9921 - val_loss: 0.0809 - val_accuracy: 0.9783
# Epoch 23/1000
# 110/110 [==============================] - 34s 313ms/step - loss: 0.0169 - accuracy: 0.9966 - val_loss: 0.0110 - val_accuracy: 0.9982
# Epoch 24/1000
# 110/110 [==============================] - 34s 312ms/step - loss: 0.0097 - accuracy: 0.9979 - val_loss: 0.0131 - val_accuracy: 0.9974
# Epoch 25/1000
# 110/110 [==============================] - 34s 307ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.0095 - val_accuracy: 0.9985
# Epoch 26/1000
# 110/110 [==============================] - 34s 312ms/step - loss: 0.0105 - accuracy: 0.9976 - val_loss: 0.0103 - val_accuracy: 0.9983
# Epoch 27/1000
# 110/110 [==============================] - 34s 314ms/step - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.0110 - val_accuracy: 0.9978
# Epoch 28/1000
# 110/110 [==============================] - 35s 318ms/step - loss: 0.0116 - accuracy: 0.9975 - val_loss: 0.0087 - val_accuracy: 0.9986
# Epoch 29/1000
# 110/110 [==============================] - 35s 316ms/step - loss: 0.0091 - accuracy: 0.9981 - val_loss: 0.0105 - val_accuracy: 0.9976
# Epoch 30/1000
# 110/110 [==============================] - 35s 316ms/step - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.0081 - val_accuracy: 0.9989
# Epoch 31/1000
# 110/110 [==============================] - 35s 315ms/step - loss: 1.9259 - accuracy: 0.7214 - val_loss: 3.2053 - val_accuracy: 0.5012
# Epoch 32/1000
# 110/110 [==============================] - 35s 315ms/step - loss: 2.8239 - accuracy: 0.5045 - val_loss: 2.4763 - val_accuracy: 0.5057
# Epoch 33/1000
# 110/110 [==============================] - 35s 315ms/step - loss: 2.1739 - accuracy: 0.5070 - val_loss: 1.9025 - val_accuracy: 0.5055
# Epoch 34/1000
# 110/110 [==============================] - 34s 312ms/step - loss: 1.6839 - accuracy: 0.5044 - val_loss: 1.4911 - val_accuracy: 0.5028
# Epoch 35/1000
# 110/110 [==============================] - 35s 314ms/step - loss: 1.3663 - accuracy: 0.5013 - val_loss: 1.2678 - val_accuracy: 0.5038
# Epoch 36/1000
# 110/110 [==============================] - 35s 315ms/step - loss: 1.2069 - accuracy: 0.5105 - val_loss: 1.1634 - val_accuracy: 0.5175
# Epoch 37/1000
# 110/110 [==============================] - 34s 312ms/step - loss: 1.1374 - accuracy: 0.5247 - val_loss: 1.1207 - val_accuracy: 0.5286
# Epoch 38/1000
# 110/110 [==============================] - 35s 322ms/step - loss: 1.1088 - accuracy: 0.5327 - val_loss: 1.1001 - val_accuracy: 0.5363
# Epoch 39/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 1.0957 - accuracy: 0.5378 - val_loss: 1.0925 - val_accuracy: 0.5397
# Epoch 40/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 1.0906 - accuracy: 0.5394 - val_loss: 1.0900 - val_accuracy: 0.5394
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping

# %%
plt.plot(log.history['accuracy'], label = 'mokymo')
plt.plot(log.history['val_accuracy'], label = 'validavimo')
plt.ylabel('tikslumas')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
plt.plot(log.history['loss'], '--', label = 'mokymo')
plt.plot(log.history['val_loss'], '--', label = 'validavimo')
plt.ylabel('netektis')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
model.save("data/ncbi_02/model_gru_noise_256")
# Out:
# 2021-11-12 15:05:42.740480: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_2_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_2_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_noise_256/assets
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_noise_256/assets
