# %% [markdown]
# ## Character-level recurrent sequence-to-sequence model

# %% [markdown]
# Example from https://keras.io/examples/nlp/lstm_seq2seq/
# Older post https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %%
import numpy as np
import pandas as pd
from itertools import chain
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 8)

# %%
with np.load('data/ncbi_02/dataset.npz', allow_pickle = True) as data:
    encoder_input_data = data['encoder_input_data']
    decoder_input_data = data['decoder_input_data']
    decoder_target_data = data['decoder_target_data']
    token_index = data['token_index'].tolist()

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)
print(token_index)
# Out:
# (4368, 3822, 4)
# (4368, 3822, 4)
# (4368, 3822, 4)
# {'A': 0, 'C': 1, 'G': 2, 'T': 3}

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13932916814079981113
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 6751453184
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 5016054323881208293
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 7507804160
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 12236559316958537567
# physical_device_desc: "device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]
# 2021-10-06 11:53:39.183130: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-06 11:53:39.324237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.324596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.328870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.329183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.329555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.329865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.900548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.900910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.901210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.901546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.901840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.902118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 6438 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2021-10-06 11:53:39.902481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:53:39.902764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:1 with 7160 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# ## Construct model

# %%
latent_dim = 256     # Latent dimensionality of the encoding space.
batch_size = 32      # Batch size for training.
patience = 10        # Patience for EarlyStop
epochs = 1000        # Number of epochs to train for.

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape = (None, encoder_input_data.shape[2]))
encoder = keras.layers.GRU(latent_dim, return_state = True)
encoder_outputs, state_h = encoder(encoder_inputs)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape = (None, decoder_input_data.shape[2]))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.GRU(latent_dim, return_sequences = True, return_state = True)
decoder_outputs, _ = decoder_lstm(decoder_inputs, initial_state = state_h)
decoder_dense = keras.layers.Dense(decoder_target_data.shape[2], activation = "softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
# Out:
# 2021-10-06 11:55:29.403767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.404185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.404805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.405176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.405780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.406139: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.407018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.407430: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.408072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.408851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.409753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.410395: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.411373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.412189: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.413101: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.413694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6438 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2021-10-06 11:55:29.413768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-06 11:55:29.414625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 7160 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file = 'model.png')

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# gru (GRU)                       [(None, 256), (None, 201216      input_1[0][0]
# __________________________________________________________________________________________________
# gru_1 (GRU)                     [(None, None, 256),  201216      input_2[0][0]
#                                                                  gru[0][1]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 4)      1028        gru_1[0][0]
# ==================================================================================================
# Total params: 403,460
# Trainable params: 403,460
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.compile(
    optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"]
)

es = EarlyStopping(monitor='val_loss', min_delta = 0, patience = patience, 
                   verbose = 1, restore_best_weights = True)

log = model.fit(
    [ encoder_input_data, decoder_input_data ],
    decoder_target_data,
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [ es ],
    validation_split = 0.2,
)
# Out:
# 2021-10-06 11:55:46.306611: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 2021-10-06 11:55:48.156370: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8204
# 110/110 [==============================] - 36s 311ms/step - loss: 1.3081 - accuracy: 0.3646 - val_loss: 1.2766 - val_accuracy: 0.3964
# Epoch 2/1000
# 110/110 [==============================] - 34s 307ms/step - loss: 1.2426 - accuracy: 0.4195 - val_loss: 1.2000 - val_accuracy: 0.4481
# Epoch 3/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 1.1440 - accuracy: 0.4864 - val_loss: 1.0984 - val_accuracy: 0.5147
# Epoch 4/1000
# 110/110 [==============================] - 36s 329ms/step - loss: 1.0041 - accuracy: 0.5672 - val_loss: 0.9368 - val_accuracy: 0.6067
# Epoch 5/1000
# 110/110 [==============================] - 37s 335ms/step - loss: 0.8270 - accuracy: 0.6625 - val_loss: 0.7111 - val_accuracy: 0.7272
# Epoch 6/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 0.6367 - accuracy: 0.7586 - val_loss: 0.5019 - val_accuracy: 0.8298
# Epoch 7/1000
# 110/110 [==============================] - 37s 334ms/step - loss: 0.4571 - accuracy: 0.8441 - val_loss: 0.3756 - val_accuracy: 0.8791
# Epoch 8/1000
# 110/110 [==============================] - 36s 327ms/step - loss: 0.3062 - accuracy: 0.9109 - val_loss: 0.2038 - val_accuracy: 0.9558
# Epoch 9/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.1928 - accuracy: 0.9544 - val_loss: 0.1224 - val_accuracy: 0.9805
# Epoch 10/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.1276 - accuracy: 0.9723 - val_loss: 0.0615 - val_accuracy: 0.9946
# Epoch 11/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0871 - accuracy: 0.9817 - val_loss: 0.0426 - val_accuracy: 0.9959
# Epoch 12/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0627 - accuracy: 0.9872 - val_loss: 0.3151 - val_accuracy: 0.8956
# Epoch 13/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0498 - accuracy: 0.9893 - val_loss: 0.0250 - val_accuracy: 0.9967
# Epoch 14/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0358 - accuracy: 0.9927 - val_loss: 0.0228 - val_accuracy: 0.9963
# Epoch 15/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0341 - accuracy: 0.9926 - val_loss: 0.0401 - val_accuracy: 0.9927
# Epoch 16/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0322 - accuracy: 0.9927 - val_loss: 0.0183 - val_accuracy: 0.9974
# Epoch 17/1000
# 110/110 [==============================] - 35s 321ms/step - loss: 0.0231 - accuracy: 0.9953 - val_loss: 0.0187 - val_accuracy: 0.9965
# Epoch 18/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0223 - accuracy: 0.9950 - val_loss: 0.0198 - val_accuracy: 0.9961
# Epoch 19/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0204 - accuracy: 0.9956 - val_loss: 0.0123 - val_accuracy: 0.9982
# Epoch 20/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0199 - accuracy: 0.9955 - val_loss: 0.0126 - val_accuracy: 0.9980
# Epoch 21/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0150 - accuracy: 0.9970 - val_loss: 0.0123 - val_accuracy: 0.9977
# Epoch 22/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0171 - accuracy: 0.9965 - val_loss: 0.0107 - val_accuracy: 0.9983
# Epoch 23/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0244 - accuracy: 0.9951 - val_loss: 0.0121 - val_accuracy: 0.9981
# Epoch 24/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0104 - accuracy: 0.9980 - val_loss: 0.1158 - val_accuracy: 0.9638
# Epoch 25/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0105 - accuracy: 0.9979 - val_loss: 0.0137 - val_accuracy: 0.9967
# Epoch 26/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0134 - accuracy: 0.9972 - val_loss: 0.0094 - val_accuracy: 0.9987
# Epoch 27/1000
# 110/110 [==============================] - 35s 318ms/step - loss: 0.0121 - accuracy: 0.9976 - val_loss: 0.0107 - val_accuracy: 0.9985
# Epoch 28/1000
# 110/110 [==============================] - 35s 318ms/step - loss: 0.0103 - accuracy: 0.9980 - val_loss: 0.0088 - val_accuracy: 0.9985
# Epoch 29/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0125 - accuracy: 0.9974 - val_loss: 0.0088 - val_accuracy: 0.9986
# Epoch 30/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0096 - accuracy: 0.9980 - val_loss: 0.0103 - val_accuracy: 0.9987
# Epoch 31/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.0086 - val_accuracy: 0.9984
# Epoch 32/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0108 - accuracy: 0.9977 - val_loss: 0.0090 - val_accuracy: 0.9985
# Epoch 33/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.0083 - val_accuracy: 0.9987
# Epoch 34/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0088 - accuracy: 0.9982 - val_loss: 0.0079 - val_accuracy: 0.9987
# Epoch 35/1000
# 110/110 [==============================] - 35s 318ms/step - loss: 0.0119 - accuracy: 0.9976 - val_loss: 0.0088 - val_accuracy: 0.9986
# Epoch 36/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0062 - accuracy: 0.9989 - val_loss: 0.0108 - val_accuracy: 0.9975
# Epoch 37/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0101 - accuracy: 0.9981 - val_loss: 0.0075 - val_accuracy: 0.9990
# Epoch 38/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.0135 - val_accuracy: 0.9970
# Epoch 39/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.0072 - val_accuracy: 0.9991
# Epoch 40/1000
# 110/110 [==============================] - 35s 320ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0143 - val_accuracy: 0.9962
# Epoch 41/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0085 - accuracy: 0.9984 - val_loss: 0.0071 - val_accuracy: 0.9991
# Epoch 42/1000
# 110/110 [==============================] - 35s 319ms/step - loss: 0.0060 - accuracy: 0.9989 - val_loss: 0.0153 - val_accuracy: 0.9968
# Epoch 43/1000
# 110/110 [==============================] - 36s 331ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.0069 - val_accuracy: 0.9989
# Epoch 44/1000
# 110/110 [==============================] - 36s 331ms/step - loss: 0.0271 - accuracy: 0.9951 - val_loss: 0.0082 - val_accuracy: 0.9989
# Epoch 45/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.0072 - val_accuracy: 0.9988
# Epoch 46/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.0078 - val_accuracy: 0.9981
# Epoch 47/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.0069 - val_accuracy: 0.9989
# Epoch 48/1000
# 110/110 [==============================] - 36s 331ms/step - loss: 0.0237 - accuracy: 0.9956 - val_loss: 0.0073 - val_accuracy: 0.9988
# Epoch 49/1000
# 110/110 [==============================] - 36s 328ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.0084 - val_accuracy: 0.9973
# Epoch 50/1000
# 110/110 [==============================] - 36s 329ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.0068 - val_accuracy: 0.9992
# Epoch 51/1000
# 110/110 [==============================] - 36s 329ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.0143 - val_accuracy: 0.9975
# Epoch 52/1000
# 110/110 [==============================] - 36s 328ms/step - loss: 0.0170 - accuracy: 0.9969 - val_loss: 0.0069 - val_accuracy: 0.9989
# Epoch 53/1000
# 110/110 [==============================] - 36s 329ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0444 - val_accuracy: 0.9897
# Epoch 54/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0066 - val_accuracy: 0.9992
# Epoch 55/1000
# 110/110 [==============================] - 36s 328ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0069 - val_accuracy: 0.9987
# Epoch 56/1000
# 110/110 [==============================] - 36s 329ms/step - loss: 0.0892 - accuracy: 0.9859 - val_loss: 1.5514 - val_accuracy: 0.7264
# Epoch 57/1000
# 110/110 [==============================] - 37s 333ms/step - loss: 1.3261 - accuracy: 0.7390 - val_loss: 1.1870 - val_accuracy: 0.7430
# Epoch 58/1000
# 110/110 [==============================] - 36s 332ms/step - loss: 1.4613 - accuracy: 0.6822 - val_loss: 1.7711 - val_accuracy: 0.5935
# Epoch 59/1000
# 110/110 [==============================] - 36s 331ms/step - loss: 2.2027 - accuracy: 0.4822 - val_loss: 2.1232 - val_accuracy: 0.4461
# Epoch 60/1000
# 110/110 [==============================] - 36s 330ms/step - loss: 1.8644 - accuracy: 0.4495 - val_loss: 1.6564 - val_accuracy: 0.4503
# Epoch 61/1000
# 110/110 [==============================] - 37s 336ms/step - loss: 1.4994 - accuracy: 0.4525 - val_loss: 1.3743 - val_accuracy: 0.4544
# Epoch 62/1000
# 110/110 [==============================] - 37s 333ms/step - loss: 1.3000 - accuracy: 0.4580 - val_loss: 1.2421 - val_accuracy: 0.4630
# Epoch 63/1000
# 110/110 [==============================] - 37s 335ms/step - loss: 1.2025 - accuracy: 0.4713 - val_loss: 1.1772 - val_accuracy: 0.4766
# Epoch 64/1000
# 110/110 [==============================] - 36s 331ms/step - loss: 1.1611 - accuracy: 0.4832 - val_loss: 1.1523 - val_accuracy: 0.4891
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping

# %%
plt.plot(log.history['accuracy'], label = 'mokymo')
plt.plot(log.history['val_accuracy'], label = 'validavimo')
plt.ylabel('tikslumas')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
plt.plot(log.history['loss'], '--', label = 'mokymo')
plt.plot(log.history['val_loss'], '--', label = 'validavimo')
plt.ylabel('netektis')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
model.save("data/ncbi_02/model_gru_256")
# Out:
# 2021-10-06 12:43:54.240134: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses, gru_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_256/assets
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_256/assets
