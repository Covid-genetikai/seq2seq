# %% [markdown]
# ## Character-level recurrent sequence-to-sequence model

# %% [markdown]
# Example from https://keras.io/examples/nlp/lstm_seq2seq/
# Older post https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %%
import numpy as np
import pandas as pd
from itertools import chain
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 8)

# %%
with np.load('data/ncbi_02/dataset.npz', allow_pickle = True) as data:
    encoder_input_data = data['encoder_input_data']
    decoder_input_data = data['decoder_input_data']
    decoder_target_data = data['decoder_target_data']
    token_index = data['token_index'].tolist()

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)
print(token_index)
# Out:
# (4368, 3822, 4)
# (4368, 3822, 4)
# (4368, 3822, 4)
# {'A': 0, 'C': 1, 'G': 2, 'T': 3}

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4246983612607504843
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 132644864
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 14669856025074049586
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 7507869696
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 12135535287339006813
# physical_device_desc: "device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1"
# ]
# 2021-11-12 15:46:22.514416: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.515390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.516818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.517636: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.519062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.519878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.521479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.522346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.523750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.524442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 126 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2021-11-12 15:46:22.524658: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 15:46:22.525926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:1 with 7160 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# ## Construct model

# %%
latent_dim = 256     # Latent dimensionality of the encoding space.
batch_size = 32      # Batch size for training.
patience = 10        # Patience for EarlyStop
epochs = 1000        # Number of epochs to train for.

# %%
encoder_inputs = keras.Input(shape = (None, encoder_input_data.shape[2]))
encoder = keras.layers.GRU(latent_dim, return_state = True)
encoder_outputs, state_h = encoder(encoder_inputs)

state_h = keras.layers.GaussianNoise(1.0)(state_h, training = True)
state_h = keras.layers.BatchNormalization(momentum = 0.6)(state_h)

decoder_inputs = keras.Input(shape = (None, decoder_input_data.shape[2]))

decoder = keras.layers.GRU(latent_dim, return_sequences = True, return_state = True)
decoder_outputs, _ = decoder(decoder_inputs, initial_state = state_h)
decoder_dense = keras.layers.Dense(decoder_target_data.shape[2], activation = "softmax")
decoder_outputs = decoder_dense(decoder_outputs)

parent_encoder = keras.layers.GRU(latent_dim, return_state = True)
parent_encoded, _ = parent_encoder(encoder_inputs)

mutation_encoder = keras.layers.GRU(latent_dim, return_state = True)
mutation_encoded, _ = mutation_encoder(decoder_outputs)

discriminator_input = keras.layers.concatenate([parent_encoded, mutation_encoded])
discriminator = keras.layers.Dense(1024, activation = "tanh")
discriminator = discriminator(discriminator_input)
disc_output = keras.layers.Dense(1, activation = "sigmoid")(discriminator)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], disc_output)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file = 'model.png')

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, None, 4)]    0
# __________________________________________________________________________________________________
# gru_10 (GRU)                    [(None, 256), (None, 201216      input_9[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_4 (GaussianNoise (None, 256)          0           gru_10[0][1]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, None, 4)]    0
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256)          1024        gaussian_noise_4[0][0]
# __________________________________________________________________________________________________
# gru_11 (GRU)                    [(None, None, 256),  201216      input_10[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 4)      1028        gru_11[0][0]
# __________________________________________________________________________________________________
# gru_12 (GRU)                    [(None, 256), (None, 201216      input_9[0][0]
# __________________________________________________________________________________________________
# gru_13 (GRU)                    [(None, 256), (None, 201216      dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512)          0           gru_12[0][0]
#                                                                  gru_13[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1024)         525312      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            1025        dense_6[0][0]
# ==================================================================================================
# Total params: 1,333,253
# Trainable params: 1,332,741
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.compile(
    optimizer = "rmsprop", loss = "categorical_crossentropy", metrics = ["accuracy"]
)

es = EarlyStopping(monitor='val_loss', min_delta = 0, patience = patience, 
                   verbose = 1, restore_best_weights = True)

log = model.fit(
    [ encoder_input_data, decoder_input_data ],
    decoder_target_data,
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [ es ],
    validation_split = 0.2,
)
# Out:
# 2021-11-12 15:54:44.720852: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 203.77MiB (rounded to 213665280)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2021-11-12 15:54:44.720933: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2021-11-12 15:54:44.720975: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 19, Chunks in use: 19. 4.8KiB allocated for chunks. 4.8KiB in use in bin. 108B client-requested in use in bin.
# 2021-11-12 15:54:44.720999: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721021: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 9, Chunks in use: 9. 9.2KiB allocated for chunks. 9.2KiB in use in bin. 9.0KiB client-requested in use in bin.
# 2021-11-12 15:54:44.721042: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 1, Chunks in use: 0. 3.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721066: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 10, Chunks in use: 8. 51.8KiB allocated for chunks. 41.8KiB in use in bin. 40.0KiB client-requested in use in bin.
# 2021-11-12 15:54:44.721091: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 15, Chunks in use: 12. 161.0KiB allocated for chunks. 133.0KiB in use in bin. 120.0KiB client-requested in use in bin.
# 2021-11-12 15:54:44.721112: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 24.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721131: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721149: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721167: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721185: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721206: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 7, Chunks in use: 6. 5.43MiB allocated for chunks. 4.50MiB in use in bin. 4.50MiB client-requested in use in bin.
# 2021-11-12 15:54:44.721227: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 2, Chunks in use: 2. 2.61MiB allocated for chunks. 2.61MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2021-11-12 15:54:44.721247: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 2, Chunks in use: 1. 5.00MiB allocated for chunks. 2.00MiB in use in bin. 2.00MiB client-requested in use in bin.
# 2021-11-12 15:54:44.721267: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 1, Chunks in use: 0. 4.00MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721285: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721303: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721321: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721342: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 85.18MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721380: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721399: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2021-11-12 15:54:44.721422: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Bin for 203.77MiB was 128.00MiB, Chunk State:
# 2021-11-12 15:54:44.721439: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 107442432
# 2021-11-12 15:54:44.721462: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000000 of size 1280 next 1
# 2021-11-12 15:54:44.721478: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000500 of size 256 next 2
# 2021-11-12 15:54:44.721493: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000600 of size 256 next 3
# 2021-11-12 15:54:44.721507: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000700 of size 256 next 4
# 2021-11-12 15:54:44.721521: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000800 of size 256 next 5
# 2021-11-12 15:54:44.721536: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000900 of size 256 next 8
# 2021-11-12 15:54:44.721550: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000a00 of size 256 next 20
# 2021-11-12 15:54:44.721564: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000b00 of size 256 next 21
# 2021-11-12 15:54:44.721578: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000c00 of size 256 next 11
# 2021-11-12 15:54:44.721593: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000d00 of size 256 next 13
# 2021-11-12 15:54:44.721608: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84000e00 of size 10240 next 17
# 2021-11-12 15:54:44.721622: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84003600 of size 256 next 26
# 2021-11-12 15:54:44.721637: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84003700 of size 9216 next 36
# 2021-11-12 15:54:44.721652: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f3e84005b00 of size 3328 next 6
# 2021-11-12 15:54:44.721667: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84006800 of size 12288 next 18
# 2021-11-12 15:54:44.721681: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e84009800 of size 12288 next 32
# 2021-11-12 15:54:44.721696: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e8400c800 of size 4096 next 53
# 2021-11-12 15:54:44.721711: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e8400d800 of size 4096 next 55
# 2021-11-12 15:54:44.721726: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f3e8400e800 of size 10240 next 37
# 2021-11-12 15:54:44.721740: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f3
I tensorflow/core/common_runtime/bfc_allocator.cc:1060] Free  at 7f3e85149800 of size 89315584 next 18446744073709551615
# 2021-11-12 15:54:44.722476: I tensorflow/core/common_runtime/bfc_allocator.cc:1065]      Summary of in-use Chunks by size:
# 2021-11-12 15:54:44.722496: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 19 Chunks of size 256 totalling 4.8KiB
# 2021-11-12 15:54:44.722515: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 8 Chunks of size 1024 totalling 8.0KiB
# 2021-11-12 15:54:44.722533: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1280 totalling 1.2KiB
# 2021-11-12 15:54:44.722551: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 4096 totalling 16.0KiB
# 2021-11-12 15:54:44.722568: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 6144 totalling 18.0KiB
# 2021-11-12 15:54:44.722586: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 7936 totalling 7.8KiB
# 2021-11-12 15:54:44.722603: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 8192 totalling 8.0KiB
# 2021-11-12 15:54:44.722620: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 9216 totalling 9.0KiB
# 2021-11-12 15:54:44.722638: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 10240 totalling 20.0KiB
# 2021-11-12 15:54:44.722655: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 8 Chunks of size 12288 totalling 96.0KiB
# 2021-11-12 15:54:44.722673: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 6 Chunks of size 786432 totalling 4.50MiB
# 2021-11-12 15:54:44.722690: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1298432 totalling 1.24MiB
# 2021-11-12 15:54:44.722707: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 1437696 totalling 1.37MiB
# 2021-11-12 15:54:44.722724: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 2097152 totalling 2.00MiB
# 2021-11-12 15:54:44.722741: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 9.29MiB
# 2021-11-12 15:54:44.722757: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 107442432 memory_limit_: 132644864 available bytes: 25202432 curr_region_allocation_bytes_: 265289728
# 2021-11-12 15:54:44.722784: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                       132644864
# InUse:                         9745152
# MaxInUse:                     15549184
# NumAllocs:                         282
# MaxAllocSize:                  2097152
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2021-11-12 15:54:44.722813: W tensorflow/core/common_runtime/bfc_allocator.cc:468] ******__****__***___________________________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_317694/1684057088.py in <module>
#       6                    verbose = 1, restore_best_weights = True)
#       7
# ----> 8 log = model.fit(
#       9     [ encoder_input_data, decoder_input_data ],
#      10     decoder_target_data,
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1132          training_utils.RespectCompiledTrainableState(self):
#    1133       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134       data_handler = data_adapter.get_data_handler(
#    1135           x=x,
#    1136           y=y,
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     228                **kwargs):
#     229     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 230     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     231     sample_weight_modes = broadcast_sample_weight_modes(
#     232         sample_weights, sample_weight_modes)
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1029     return x
#    1030
# -> 1031   inputs = tf.nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1032   return tf.__internal__.nest.list_to_tuple(inputs)
#    1033
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/keras/engine/data_adapter.py in _convert_numpy_and_scipy(x)
#    1024       if issubclass(x.dtype.type, np.floating):
#    1025         dtype = backend.floatx()
# -> 1026       return tf.convert_to_tensor(x, dtype=dtype)
#    1027     elif _is_scipy_sparse(x):
#    1028       return _scipy_sparse_to_sparse_tensor(x)
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1428     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1429   """
# -> 1430   return convert_to_tensor_v2(
#    1431       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#    1432
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1434 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1435   """Converts the given `value` to a `Tensor`."""
# -> 1436   return convert_to_tensor(
#    1437       value=value,
#    1438       dtype=dtype,
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# ~/.virtualenvs/seq2seq-2cC7ZY1Q/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
plt.plot(log.history['accuracy'], label = 'mokymo')
plt.plot(log.history['val_accuracy'], label = 'validavimo')
plt.ylabel('tikslumas')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
plt.plot(log.history['loss'], '--', label = 'mokymo')
plt.plot(log.history['val_loss'], '--', label = 'validavimo')
plt.ylabel('netektis')
plt.xlabel('epocha')
plt.legend()
plt.show()

# %%
model.save("data/ncbi_02/model_gru_noise_256")
# Out:
# 2021-11-12 15:05:42.740480: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_2_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_2_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_noise_256/assets
# INFO:tensorflow:Assets written to: data/ncbi_02/model_gru_noise_256/assets
